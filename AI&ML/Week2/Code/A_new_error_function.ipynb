# %%
'''A function that i really like, and that is used very often'''
# Out:
# 'A function that i really like, and that is used very often'

# %%
weight = 0.5
input = 0.3
prediciton_goal = 0.6
alpha = 0.1

 
error_derivative = ((weight * input ) - prediction_goal) **2

weight = (weight * alpha)
derivative = input * (pred - goal_pred) 
weight = weight - (alpha * derivative)

# %% [markdown]
# weight = 0.5
# input = 0.3
# prediciton_goal = 0.6
# alpha = 0.1
#
#  diese function ist eine dervivative sie berechnet den error aber auch zussammenhang zwischen error und weight
# das + bias habe ich hinzugefügt müsste aber passen die berechnung ausßerhalb der innern klammer kann durch dot product / skalarprodukt ersetzt werden'''
# error_derivative = ((weight * input ) - prediction_goal) **2
# Um uns vor zu großen weights zu schützen machen wir:'''
# weight = (weight * alpha)
